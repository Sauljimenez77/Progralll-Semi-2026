# %% [markdown]
# <a href="https://colab.research.google.com/github/Sauljimenez77/Progralll-Semi-2026/blob/main/miPrimerProyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 saludo = "Hola chicos de progra III"

 print(saludo, "Primera letra del saludo", saludo[0:4])

 num1 = 5.25
 print(num1)

 booleano = True
 print(booleano)
# Out:
# Hola chicos de progra III Primera letra del saludo Hola
# 5.25
# True

# %%
print("sumar dos numeros:")
num1 = input("Num1: ")
num2 = input("Num2: ")
respuesta = float(num1) + float(num2)
print(type(num1), type(num2), type(respuesta))

print ("Respuesta: ", respuesta)

respuesta = "Ssuma completa"
print(respuesta, type(respuesta))
# Out:
# sumar dos numeros:
# Num1: 5.5
# Num2: 6
# <class 'str'> <class 'str'> <class 'float'>
# Respuesta:  11.5
# Ssuma completa <class 'str'>

# %%
print("resta dos numeros:")
num1 = input("Num1: ")
num2 = input("Num2: ")
respuesta = float(num1) - float(num2)
print(type(num1), type(num2), type(respuesta))

print ("Respuesta: ", respuesta)

respuesta = "Ssuma completa"
print(respuesta, type(respuesta))
# Out:
# resta dos numeros:
# Num1: 5
# Num2: 3
# <class 'str'> <class 'str'> <class 'float'>
# Respuesta:  2.0
# Ssuma completa <class 'str'>

# %%
print("multiplicar dos numeros:")
num1 = input("Num1: ")
num2 = input("Num2: ")
respuesta = float(num1) * float(num2)
print(type(num1), type(num2), type(respuesta))

print ("Respuesta: ", respuesta)

respuesta = "Ssuma completa"
print(respuesta, type(respuesta))
# Out:
# multiplicar dos numeros:
# Num1: 5
# Num2: 2
# <class 'str'> <class 'str'> <class 'float'>
# Respuesta:  10.0
# Ssuma completa <class 'str'>

# %%
print("Dividir dos numeros:")
num1 = input("Num1: ")
num2 = input("Num2: ")
respuesta = float(num1) / float(num2)
print(type(num1), type(num2), type(respuesta))

print ("Respuesta: ", respuesta)

respuesta = "Ssuma completa"
print(respuesta, type(respuesta))
# Out:
# Dividir dos numeros:
# Num1: 4
# Num2: 2
# <class 'str'> <class 'str'> <class 'float'>
# Respuesta:  2.0
# Ssuma completa <class 'str'>
